# %% [markdown]
# ___
# ### Notebook - Application Data Analysis
# ___

# %% [markdown]
# <table class=\table-bordered table-hover table-condensed\><caption><h1><center>Data Set Description as given on Kaggle - Application file only</h1></center></caption><thead>
# <tr><th title=\Field #2\>Row</th><th title=\Field #3\>Description</th><th title=\Field #4\>Special</th></tr></thead>
# <tbody>
# <tr><td>SK_ID_CURR</td><td>ID of loan in our sample</td><td> </td></tr>
# <tr><td>TARGET</td><td>Target variable (1 - client with payment difficulties: he/she had late payment more than X days on at least one of the first Y installments of the loan in our sample, 0 - all other cases)</td><td> </td></tr>
# <tr><td>NAME_CONTRACT_TYPE</td><td>Identification if loan is cash or revolving</td><td> </td></tr>
# <tr><td>CODE_GENDER</td><td>Gender of the client</td><td> </td></tr>
# <tr><td>FLAG_OWN_CAR</td><td>Flag if the client owns a car</td><td> </td></tr>
# <tr><td>FLAG_OWN_REALTY</td><td>Flag if client owns a house or flat</td><td> </td></tr>
# <tr><td>CNT_CHILDREN</td><td>Number of children the client has</td><td> </td></tr>
# <tr><td>AMT_INCOME_TOTAL</td><td>Income of the client</td><td> </td></tr>
# <tr><td>AMT_CREDIT</td><td>Credit amount of the loan</td><td> </td></tr>
# <tr><td>AMT_ANNUITY</td><td>Loan annuity</td><td> </td></tr>
# <tr><td>AMT_GOODS_PRICE</td><td>For consumer loans it is the price of the goods for which the loan is given</td><td> </td></tr>
# <tr><td>NAME_TYPE_SUITE</td><td>Who was accompanying client when he was applying for the loan</td><td> </td></tr>
# <tr><td>NAME_INCOME_TYPE</td><td>Clients income type (businessman, working, maternity leave,�)</td><td> </td></tr>
# <tr><td>NAME_EDUCATION_TYPE</td><td>Level of highest education the client achieved</td><td> </td></tr>
# <tr><td>NAME_FAMILY_STATUS</td><td>Family status of the client</td><td> </td></tr>
# <tr><td>NAME_HOUSING_TYPE</td><td>What is the housing situation of the client (renting, living with parents, ...)</td><td> </td></tr>
# <tr><td>REGION_POPULATION_RELATIVE</td><td>Normalized population of region where client lives (higher number means the client lives in more populated region)</td><td>normalized </td></tr>
# <tr><td>DAYS_BIRTH</td><td>Client&#39;s age in days at the time of application</td><td>time only relative to the application</td></tr>
# <tr><td>DAYS_EMPLOYED</td><td>How many days before the application the person started current employment</td><td>time only relative to the application</td></tr>
# <tr><td>DAYS_REGISTRATION</td><td>How many days before the application did client change his registration</td><td>time only relative to the application</td></tr>
# <tr><td>DAYS_ID_PUBLISH</td><td>How many days before the application did client change the identity document with which he applied for the loan</td><td>time only relative to the application</td></tr>
# <tr><td>OWN_CAR_AGE</td><td>Age of client&#39;s car</td><td> </td></tr>
# <tr><td>FLAG_MOBIL</td><td>Did client provide mobile phone (1=YES, 0=NO)</td><td> </td></tr>
# <tr><td>FLAG_EMP_PHONE</td><td>Did client provide work phone (1=YES, 0=NO)</td><td> </td></tr>
# <tr><td>FLAG_WORK_PHONE</td><td>Did client provide home phone (1=YES, 0=NO)</td><td> </td></tr>
# <tr><td>FLAG_CONT_MOBILE</td><td>Was mobile phone reachable (1=YES, 0=NO)</td><td> </td></tr>
# <tr><td>FLAG_PHONE</td><td>Did client provide home phone (1=YES, 0=NO)</td><td> </td></tr>
# <tr><td>FLAG_EMAIL</td><td>Did client provide email (1=YES, 0=NO)</td><td> </td></tr>
# <tr><td>OCCUPATION_TYPE</td><td>What kind of occupation does the client have</td><td> </td></tr>
# <tr><td>CNT_FAM_MEMBERS</td><td>How many family members does client have</td><td> </td></tr>
# <tr><td>REGION_RATING_CLIENT</td><td>Our rating of the region where client lives (1,2,3)</td><td> </td></tr>
# <tr><td>REGION_RATING_CLIENT_W_CITY</td><td>Our rating of the region where client lives with taking city into account (1,2,3)</td><td> </td></tr>
# <tr><td>WEEKDAY_APPR_PROCESS_START</td><td>On which day of the week did the client apply for the loan</td><td> </td></tr>
# <tr><td>HOUR_APPR_PROCESS_START</td><td>Approximately at what hour did the client apply for the loan</td><td>rounded</td></tr>
# <tr><td>REG_REGION_NOT_LIVE_REGION</td><td>Flag if client&#39;s permanent address does not match contact address (1=different, 0=same, at region level)</td><td> </td></tr>
# <tr><td>REG_REGION_NOT_WORK_REGION</td><td>Flag if client&#39;s permanent address does not match work address (1=different, 0=same, at region level)</td><td> </td></tr>
# <tr><td>LIVE_REGION_NOT_WORK_REGION</td><td>Flag if client&#39;s contact address does not match work address (1=different, 0=same, at region level)</td><td> </td></tr>
# <tr><td>REG_CITY_NOT_LIVE_CITY</td><td>Flag if client&#39;s permanent address does not match contact address (1=different, 0=same, at city level)</td><td> </td></tr>
# <tr><td>REG_CITY_NOT_WORK_CITY</td><td>Flag if client&#39;s permanent address does not match work address (1=different, 0=same, at city level)</td><td> </td></tr>
# <tr><td>LIVE_CITY_NOT_WORK_CITY</td><td>Flag if client&#39;s contact address does not match work address (1=different, 0=same, at city level)</td><td> </td></tr>
# <tr><td>ORGANIZATION_TYPE</td><td>Type of organization where client works</td><td> </td></tr>
# <tr><td>EXT_SOURCE_1</td><td>Normalized score from external data source</td><td>normalized</td></tr>
# <tr><td>EXT_SOURCE_2</td><td>Normalized score from external data source</td><td>normalized</td></tr>
# <tr><td>EXT_SOURCE_3</td><td>Normalized score from external data source</td><td>normalized</td></tr>
# <tr><td>APARTMENTS_AVG</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>BASEMENTAREA_AVG</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>YEARS_BEGINEXPLUATATION_AVG</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>YEARS_BUILD_AVG</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>COMMONAREA_AVG</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>ELEVATORS_AVG</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>ENTRANCES_AVG</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>FLOORSMAX_AVG</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>FLOORSMIN_AVG</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>LANDAREA_AVG</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>LIVINGAPARTMENTS_AVG</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>LIVINGAREA_AVG</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>NONLIVINGAPARTMENTS_AVG</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>NONLIVINGAREA_AVG</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>APARTMENTS_MODE</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>BASEMENTAREA_MODE</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>YEARS_BEGINEXPLUATATION_MODE</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>YEARS_BUILD_MODE</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>COMMONAREA_MODE</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>ELEVATORS_MODE</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>ENTRANCES_MODE</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>FLOORSMAX_MODE</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>FLOORSMIN_MODE</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>LANDAREA_MODE</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>LIVINGAPARTMENTS_MODE</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>LIVINGAREA_MODE</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>NONLIVINGAPARTMENTS_MODE</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>NONLIVINGAREA_MODE</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>APARTMENTS_MEDI</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>BASEMENTAREA_MEDI</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>YEARS_BEGINEXPLUATATION_MEDI</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>YEARS_BUILD_MEDI</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>COMMONAREA_MEDI</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>ELEVATORS_MEDI</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>ENTRANCES_MEDI</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>FLOORSMAX_MEDI</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>FLOORSMIN_MEDI</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>LANDAREA_MEDI</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>LIVINGAPARTMENTS_MEDI</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>LIVINGAREA_MEDI</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>NONLIVINGAPARTMENTS_MEDI</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>NONLIVINGAREA_MEDI</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>FONDKAPREMONT_MODE</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>HOUSETYPE_MODE</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>TOTALAREA_MODE</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>WALLSMATERIAL_MODE</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>EMERGENCYSTATE_MODE</td><td>Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor</td><td>normalized</td></tr>
# <tr><td>OBS_30_CNT_SOCIAL_CIRCLE</td><td>How many observation of client&#39;s social surroundings with observable 30 DPD (days past due) default</td><td> </td></tr>
# <tr><td>DEF_30_CNT_SOCIAL_CIRCLE</td><td>How many observation of client&#39;s social surroundings defaulted on 30 DPD (days past due) </td><td> </td></tr>
# <tr><td>OBS_60_CNT_SOCIAL_CIRCLE</td><td>How many observation of client&#39;s social surroundings with observable 60 DPD (days past due) default</td><td> </td></tr>
# <tr><td>DEF_60_CNT_SOCIAL_CIRCLE</td><td>How many observation of client&#39;s social surroundings defaulted on 60 (days past due) DPD</td><td> </td></tr>
# <tr><td>DAYS_LAST_PHONE_CHANGE</td><td>How many days before application did client change phone</td><td> </td></tr>
# <tr><td>FLAG_DOCUMENT_2</td><td>Did client provide document 2</td><td> </td></tr>
# <tr><td>FLAG_DOCUMENT_3</td><td>Did client provide document 3</td><td> </td></tr>
# <tr><td>FLAG_DOCUMENT_4</td><td>Did client provide document 4</td><td> </td></tr>
# <tr><td>FLAG_DOCUMENT_5</td><td>Did client provide document 5</td><td> </td></tr>
# <tr><td>FLAG_DOCUMENT_6</td><td>Did client provide document 6</td><td> </td></tr>
# <tr><td>FLAG_DOCUMENT_7</td><td>Did client provide document 7</td><td> </td></tr>
# <tr><td>FLAG_DOCUMENT_8</td><td>Did client provide document 8</td><td> </td></tr>
# <tr><td>FLAG_DOCUMENT_9</td><td>Did client provide document 9</td><td> </td></tr>
# <tr><td>FLAG_DOCUMENT_10</td><td>Did client provide document 10</td><td> </td></tr>
# <tr><td>FLAG_DOCUMENT_11</td><td>Did client provide document 11</td><td> </td></tr>
# <tr><td>FLAG_DOCUMENT_12</td><td>Did client provide document 12</td><td> </td></tr>
# <tr><td>FLAG_DOCUMENT_13</td><td>Did client provide document 13</td><td> </td></tr>
# <tr><td>FLAG_DOCUMENT_14</td><td>Did client provide document 14</td><td> </td></tr>
# <tr><td>FLAG_DOCUMENT_15</td><td>Did client provide document 15</td><td> </td></tr>
# <tr><td>FLAG_DOCUMENT_16</td><td>Did client provide document 16</td><td> </td></tr>
# <tr><td>FLAG_DOCUMENT_17</td><td>Did client provide document 17</td><td> </td></tr>
# <tr><td>FLAG_DOCUMENT_18</td><td>Did client provide document 18</td><td> </td></tr>
# <tr><td>FLAG_DOCUMENT_19</td><td>Did client provide document 19</td><td> </td></tr>
# <tr><td>FLAG_DOCUMENT_20</td><td>Did client provide document 20</td><td> </td></tr>
# <tr><td>FLAG_DOCUMENT_21</td><td>Did client provide document 21</td><td> </td></tr>
# <tr><td>AMT_REQ_CREDIT_BUREAU_HOUR</td><td>Number of enquiries to Credit Bureau about the client one hour before application</td><td> </td></tr>
# <tr><td>AMT_REQ_CREDIT_BUREAU_DAY</td><td>Number of enquiries to Credit Bureau about the client one day before application (excluding one hour before application)</td><td> </td></tr>
# <tr><td>AMT_REQ_CREDIT_BUREAU_WEEK</td><td>Number of enquiries to Credit Bureau about the client one week before application (excluding one day before application)</td><td> </td></tr>
# <tr><td>AMT_REQ_CREDIT_BUREAU_MON</td><td>Number of enquiries to Credit Bureau about the client one month before application (excluding one week before application)</td><td> </td></tr>
# <tr><td>AMT_REQ_CREDIT_BUREAU_QRT</td><td>Number of enquiries to Credit Bureau about the client 3 month before application (excluding one month before application)</td><td> </td></tr>
# <tr><td>AMT_REQ_CREDIT_BUREAU_YEAR</td><td>Number of enquiries to Credit Bureau about the client one day year (excluding last 3 months before application)</td><td> </td></tr>
# </tbody>
# </table>

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from io import BytesIO
import matplotlib.pyplot as plt
import seaborn as sns
# Clearing up memory
import gc

# Featuretools for automated feature engineering
import featuretools as ft
ft.__version__
# Out:
# '0.2.1'

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
from google.cloud import storage
client = storage.Client()
bucket = client.get_bucket('ml_project_hns')

def readCsv(input_fname: str, bucket_name:storage.bucket.Bucket)-> pd.DataFrame:
    blob = storage.blob.Blob(input_fname,bucket_name)
    content = blob.download_as_string()
    return(pd.read_csv(BytesIO(content)))

# %%
# Read the datasets
df_kaggle_train = readCsv('application_train.csv', bucket)
df_kaggle_test = readCsv('application_test.csv', bucket)

# %%
print("Shape of Train data:", df_kaggle_train.shape)
print("Shape of Test data:", df_kaggle_test.shape)
# Out:
# Shape of Train data: (307511, 122)
# Shape of Test data: (48744, 121)

# %%
# The difference in shape of the two dataframes is because for test dataset, we dont have the TARGET variable
print(df_kaggle_train['TARGET'].unique())
# Add target variable into test dataset with value that is not present in the train dataset TARGET variable
#  so that the two dataframes can be recreated
df_kaggle_test['TARGET'] = -1
# Join the test and train dataframes
df_kaggle = pd.concat([df_kaggle_train, df_kaggle_test], sort=False)
df_kaggle.shape
# Out:
# [1 0]
# (356255, 122)

# %%
pd.DataFrame(df_kaggle.dtypes, columns={'dtype'}).join(df_kaggle.describe(include='all').T)
# Out:
#                                 dtype   count unique  \
# SK_ID_CURR                      int64  356255    NaN
# TARGET                          int64  356255    NaN
# NAME_CONTRACT_TYPE             object  356255      2
# CODE_GENDER                    object  356255      3
# FLAG_OWN_CAR                   object  356255      2
# FLAG_OWN_REALTY                object  356255      2
# CNT_CHILDREN                    int64  356255    NaN
# AMT_INCOME_TOTAL              float64  356255    NaN
# AMT_CREDIT                    float64  356255    NaN
# AMT_ANNUITY                   float64  356219    NaN
# AMT_GOODS_PRICE               float64  355977    NaN
# NAME_TYPE_SUITE                object  354052      7
# NAME_INCOME_TYPE               object  356255      8
# NAME_EDUCATION_TYPE            object  356255      5
# NAME_FAMILY_STATUS             object  356255      6
# NAME_HOUSING_TYPE              object  356255      6
# REGION_POPULATION_RELATIVE    float64  356255    NaN
# ...

# %% [markdown]
# All flag variables are categorical. Apart from that, there might be other variables which are categorical but are read as numeric. So a detailed analysis is required for proper data types.
#
# All of int columns which are flags (indicating presence or absence) are categorical variables. SK_ID_CURR is a ordinal variable but since it wont be used in the model as a feature (as its an ID field), ignore that variable. Apart from those, TARGET, REG_REGION_NOT_LIVE_REGION, REG_REGION_NOT_WORK_REGION, LIVE_REGION_NOT_WORK_REGION, REG_CITY_NOT_LIVE_CITY, REG_CITY_NOT_WORK_CITY and LIVE_CITY_NOT_WORK_CITY are all categorical variables. All the remaining columns (CNT_CHILDREN, DAYS_BIRTH, DAYS_EMPLOYED, DAYS_ID_PUBLISH, REGION_RATING_CLIENT, REGION_RATING_CLIENT_W_CITY and HOUR_APPR_PROCESS_START) are continuous variables.

# %%
# Reduce variable data for Train and Test data
cols = ['CNT_CHILDREN', 'DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_ID_PUBLISH', 'REGION_RATING_CLIENT', 
          'REGION_RATING_CLIENT_W_CITY', 'HOUR_APPR_PROCESS_START']
df_kaggle[cols] = df_kaggle[cols].astype(np.int16)
cols = df_kaggle.select_dtypes(include=['int64']).columns
cols = cols.drop('SK_ID_CURR')
df_kaggle[cols] = df_kaggle[cols].astype('category')
cols = df_kaggle.select_dtypes(include=['object']).columns
df_kaggle[cols] = df_kaggle[cols].astype('category')
df_kaggle.dtypes
# Out:
# SK_ID_CURR                         int64
# TARGET                          category
# NAME_CONTRACT_TYPE              category
# CODE_GENDER                     category
# FLAG_OWN_CAR                    category
# FLAG_OWN_REALTY                 category
# CNT_CHILDREN                       int16
# AMT_INCOME_TOTAL                 float64
# AMT_CREDIT                       float64
# AMT_ANNUITY                      float64
# AMT_GOODS_PRICE                  float64
# NAME_TYPE_SUITE                 category
# NAME_INCOME_TYPE                category
# NAME_EDUCATION_TYPE             category
# NAME_FAMILY_STATUS              category
# NAME_HOUSING_TYPE               category
# REGION_POPULATION_RELATIVE       float64
# DAYS_BIRTH                         int16
# DAYS_EMPLOYED                      int16
# DAYS_REGISTRATION                float64
# DAYS_ID_PUBLISH                    int16
# OWN_CAR_AGE                      float64
# FLAG_MOBIL                      category
# ...

# %% [markdown]
# ### Missing data analysis

# %%
# Get columns having missing data
desc = pd.DataFrame(df_kaggle.dtypes, columns=['type']).join(df_kaggle.describe(include='all').T)
desc['missing_count'] = (df_kaggle['TARGET'].size - desc['count'])
desc['percent_missing'] = (df_kaggle['TARGET'].size - desc['count'])*100/df_kaggle['TARGET'].size
desc = desc[desc['count']<df_kaggle['TARGET'].size][['count','percent_missing', 'type', 'missing_count']]
desc.sort_values('percent_missing', ascending=True, inplace=True)
desc
# Out:
#                                count percent_missing      type missing_count
# DAYS_LAST_PHONE_CHANGE        356254     0.000280698   float64             1
# CNT_FAM_MEMBERS               356253     0.000561396   float64             2
# AMT_ANNUITY                   356219       0.0101051   float64            36
# AMT_GOODS_PRICE               355977        0.078034   float64           278
# EXT_SOURCE_2                  355587        0.187506   float64           668
# DEF_60_CNT_SOCIAL_CIRCLE      355205        0.294733   float64          1050
# OBS_60_CNT_SOCIAL_CIRCLE      355205        0.294733   float64          1050
# DEF_30_CNT_SOCIAL_CIRCLE      355205        0.294733   float64          1050
# OBS_30_CNT_SOCIAL_CIRCLE      355205        0.294733   float64          1050
# NAME_TYPE_SUITE               354052        0.618377  category          2203
# AMT_REQ_CREDIT_BUREAU_MON     308687         13.3522   float64         47568
# ...

# %%
missing_cols = desc.index
print(missing_cols.size)
missing_cols = missing_cols.insert(item="SK_ID_CURR", loc=missing_cols.size)
print(missing_cols.size)
# Out:
# 67
# 68

# %%
print(("Out of {} columns in the dataset, {} have missing data with minimum {} and maximum {}"
       " missing data".format(df_kaggle.shape[1], desc.shape[0], np.round(desc.percent_missing.min(),5),
                             np.round(desc.percent_missing.max(),5))))
# Out:
# Out of 122 columns in the dataset, 67 have missing data with minimum 0.00028 and maximum 69.71411 missing data

# %%
import missingno as mno
mno.bar(df_kaggle[missing_cols], fontsize=10)

# %%
mno.dendrogram(df_kaggle[missing_cols])

# %% [markdown]
# ### Categorical Fields missing data analysis

# %%
desc[desc['type']=='category']
# Out:
#                       count percent_missing      type missing_count
# NAME_TYPE_SUITE      354052        0.618377  category          2203
# OCCUPATION_TYPE      244259          31.437  category        111996
# EMERGENCYSTATE_MODE  188291         47.1471  category        167964
# HOUSETYPE_MODE       178339         49.9406  category        177916
# WALLSMATERIAL_MODE   176021         50.5913  category        180234
# FONDKAPREMONT_MODE   113163         68.2354  category        243092

# %%
# NAME_TYPE_SUITE analysis
df_kaggle.groupby('NAME_TYPE_SUITE').count().reset_index()[['NAME_TYPE_SUITE','SK_ID_CURR']]
# Out:
#    NAME_TYPE_SUITE  SK_ID_CURR
# 0         Children        3675
# 1           Family       46030
# 2  Group of people         320
# 3          Other_A         975
# 4          Other_B        1981
# 5  Spouse, partner       12818
# 6    Unaccompanied      288253

# %%
# For the records having missing NAME_TYPE_SUITE, we filled those with Unaccompanied
df_kaggle.fillna(value={'NAME_TYPE_SUITE':'Unaccompanied'}, inplace=True)

# %%
# OCCUPATION_TYPE analysis
df_kaggle.groupby('OCCUPATION_TYPE').count().reset_index()[['OCCUPATION_TYPE','SK_ID_CURR']]
# Out:
#           OCCUPATION_TYPE  SK_ID_CURR
# 0             Accountants       11441
# 1          Cleaning staff        5309
# 2           Cooking staff        6840
# 3              Core staff       31931
# 4                 Drivers       21376
# 5                HR staff         667
# 6   High skill tech staff       13234
# 7                IT staff         607
# 8                Laborers       63841
# 9      Low-skill Laborers        2365
# 10               Managers       24945
# 11         Medicine staff        9853
# 12  Private service staff        3107
# 13          Realty agents         889
# 14            Sales staff       37174
# 15            Secretaries        1518
# 16         Security staff        7636
# 17   Waiters/barmen staff        1526

# %%
# For missing OCCUPATION_TYPE records, make the occupation as 'Unemployed/Not Specified'
df_kaggle['OCCUPATION_TYPE'].cat.add_categories('Unemployed/Not Specified', inplace=True)
df_kaggle.fillna(value={'OCCUPATION_TYPE':'Unemployed/Not Specified'}, inplace=True)

# %%
# Remaining 4 categorical fields are associated with the house the client is living in
# So lets compare the missing values of these categorical fields when the client does not own the house/apartment
#    and also when client owns the house/apartment.
count_no_own_rcd = df_kaggle[df_kaggle.FLAG_OWN_REALTY=='N']['FLAG_OWN_REALTY'].size
count_own_rcd = df_kaggle[df_kaggle.FLAG_OWN_REALTY=='Y']['FLAG_OWN_REALTY'].size
temp_desc = df_kaggle[df_kaggle.FLAG_OWN_REALTY=='N'][['EMERGENCYSTATE_MODE','HOUSETYPE_MODE', 'WALLSMATERIAL_MODE',
        'FONDKAPREMONT_MODE']].describe(include='all').T
temp_desc['missing_count'] = count_no_own_rcd - temp_desc['count']
temp_desc['percent_missing'] = temp_desc['missing_count']*100/count_no_own_rcd
temp_desc['FLAG_OWN_REALTY'] = 'N'
temp_desc_1 = df_kaggle[df_kaggle.FLAG_OWN_REALTY=='Y'][['EMERGENCYSTATE_MODE','HOUSETYPE_MODE', 'WALLSMATERIAL_MODE',
        'FONDKAPREMONT_MODE']].describe(include='all').T
temp_desc_1['missing_count'] = count_own_rcd - temp_desc_1['count']
temp_desc_1['percent_missing'] = temp_desc_1['missing_count']*100/count_own_rcd
temp_desc_1['FLAG_OWN_REALTY'] = 'Y'
temp_desc_2 = df_kaggle[['EMERGENCYSTATE_MODE','HOUSETYPE_MODE', 'WALLSMATERIAL_MODE', 'FONDKAPREMONT_MODE'
            ]].describe(include='all').T
temp_desc_2['missing_count'] = count_own_rcd + count_no_own_rcd - temp_desc_2['count']
temp_desc_2['percent_missing'] = temp_desc_2['missing_count']*100/(count_own_rcd + count_no_own_rcd)
temp_desc_2['FLAG_OWN_REALTY'] = 'ALL'
desc_1 = pd.concat([temp_desc, temp_desc_1, temp_desc_2]).reset_index()
desc_1.sort_values(by=['index','FLAG_OWN_REALTY'], inplace=True)
desc_1
# df_kaggle.groupby('EMERGENCYSTATE_MODE').count().reset_index()[['EMERGENCYSTATE_MODE','SK_ID_CURR']]
# Out:
#                   index   count unique               top    freq  \
# 8   EMERGENCYSTATE_MODE  188291      2                No  185607
# 0   EMERGENCYSTATE_MODE   55810      2                No   54861
# 4   EMERGENCYSTATE_MODE  132481      2                No  130746
# 11   FONDKAPREMONT_MODE  113163      4  reg oper account   85954
# 3    FONDKAPREMONT_MODE   33303      4  reg oper account   25086
# 7    FONDKAPREMONT_MODE   79860      4  reg oper account   60868
# 9        HOUSETYPE_MODE  178339      3    block of flats  175162
# 1        HOUSETYPE_MODE   52710      3    block of flats   51599
# 5        HOUSETYPE_MODE  125629      3    block of flats  123563
# 10   WALLSMATERIAL_MODE  176021      7             Panel   77309
# 2    WALLSMATERIAL_MODE   51779      7             Panel   22538
# 6    WALLSMATERIAL_MODE  124242      7             Panel   54771
#
#    missing_count percent_missing FLAG_OWN_REALTY
# 8         167964         47.1471             ALL
# ...

# %%
# Nothing conclusive can be said about the missing data link of these 4 fields w.r.t. the house ownership
# So will analyze it in the same way as we did for the other fields

# EMERGENCYSTATE_MODE analysis
df_kaggle.groupby('EMERGENCYSTATE_MODE').count().reset_index()[['EMERGENCYSTATE_MODE','SK_ID_CURR']]
# Out:
#   EMERGENCYSTATE_MODE  SK_ID_CURR
# 0                  No      185607
# 1                 Yes        2684

# %%
# For the records having missing EMERGENCYSTATE_MODE, we filled those with No
df_kaggle.fillna(value={'EMERGENCYSTATE_MODE':'No'}, inplace=True)

# %%
# FONDKAPREMONT_MODE analysis
df_kaggle.groupby('FONDKAPREMONT_MODE').count().reset_index()[['FONDKAPREMONT_MODE','SK_ID_CURR']]
# Out:
#       FONDKAPREMONT_MODE  SK_ID_CURR
# 0          not specified        6600
# 1       org spec account        6539
# 2       reg oper account       85954
# 3  reg oper spec account       14070

# %%
# For the records having missing FONDKAPREMONT_MODE, we filled those with 'not specified'
df_kaggle.fillna(value={'FONDKAPREMONT_MODE':'not specified'}, inplace=True)

# %%
# HOUSETYPE_MODE analysis
df_kaggle.groupby('HOUSETYPE_MODE').count().reset_index()[['HOUSETYPE_MODE','SK_ID_CURR']]
# Out:
#      HOUSETYPE_MODE  SK_ID_CURR
# 0    block of flats      175162
# 1  specific housing        1761
# 2    terraced house        1416

# %%
# For missing HOUSETYPE_MODE records, make the occupation as 'Not Specified'
df_kaggle['HOUSETYPE_MODE'].cat.add_categories('Not Specified', inplace=True)
df_kaggle.fillna(value={'HOUSETYPE_MODE':'Not Specified'}, inplace=True)

# %%
# WALLSMATERIAL_MODE analysis
df_kaggle.groupby('WALLSMATERIAL_MODE').count().reset_index()[['WALLSMATERIAL_MODE','SK_ID_CURR']]
# Out:
#   WALLSMATERIAL_MODE  SK_ID_CURR
# 0              Block       10681
# 1              Mixed        2649
# 2         Monolithic        2068
# 3             Others        1909
# 4              Panel       77309
# 5       Stone, brick       75249
# 6             Wooden        6156

# %%
# For missing WALLSMATERIAL_MODE records, make the occupation as 'Not Specified'
df_kaggle['WALLSMATERIAL_MODE'].cat.add_categories('Not Specified', inplace=True)
df_kaggle.fillna(value={'WALLSMATERIAL_MODE':'Not Specified'}, inplace=True)

# %% [markdown]
# ### Countinuous data fields missing value analysis

# %%
# OWN_CAR_AGE field analysis
print('FLAG_OWN_CAR summary')
print(df_kaggle.groupby('FLAG_OWN_CAR').count().reset_index()[['FLAG_OWN_CAR', 'SK_ID_CURR']])
print("\nOWN_CAR_AGE is null:", df_kaggle['OWN_CAR_AGE'].isnull().sum(axis=0))
print("OWN_CAR_AGE is zero:", df_kaggle[df_kaggle.OWN_CAR_AGE == 0]['OWN_CAR_AGE'].count())
print('\nFLAG_OWN_CAR summary when OWN_CAR_AGE is missing')
print(df_kaggle[df_kaggle['OWN_CAR_AGE'].isnull()].groupby(['FLAG_OWN_CAR']).count().reset_index()[
    ['FLAG_OWN_CAR', 'SK_ID_CURR']])
# Out:
# FLAG_OWN_CAR summary
#   FLAG_OWN_CAR  SK_ID_CURR
# 0            N      235235
# 1            Y      121020
#
# OWN_CAR_AGE is null: 235241
# OWN_CAR_AGE is zero: 2252
#
# FLAG_OWN_CAR summary when OWN_CAR_AGE is missing
#   FLAG_OWN_CAR  SK_ID_CURR
# 0            N      235235
# 1            Y           6

# %%
# For the records where car age is missing but the FLAG_OWN_CAR is Y, change the flag to N 
df_kaggle['FLAG_OWN_CAR'] = df_kaggle[['FLAG_OWN_CAR', 'OWN_CAR_AGE']].apply(lambda x: 'N' if 
                                                (not(pd.notnull(x[1])) & (x[0]=="Y")) else x[0], axis=1)
# When the person does not own a car, the car age is truely null. So change it to -1 when own car flag is N
# car age of zero may mean that the car is very recently purchased.
df_kaggle.fillna(value={'OWN_CAR_AGE':-1}, inplace=True)

# %%
# EXT_SOURCE_1, EXT_SOURCE_2, EXT_SOURCE_3 missing data analysis
print("EXT_SOURCE_1: Minimum Value={:.8f} Maximim Value={:.8f}".format(df_kaggle.EXT_SOURCE_1.min(), 
                df_kaggle.EXT_SOURCE_1.max()))
print("EXT_SOURCE_2: Minimum Value={:.8f} Maximim Value={:.8f}".format(df_kaggle.EXT_SOURCE_2.min(), 
                df_kaggle.EXT_SOURCE_2.max()))
print("EXT_SOURCE_3: Minimum Value={:.8f} Maximim Value={:.8f}".format(df_kaggle.EXT_SOURCE_3.min(), 
                df_kaggle.EXT_SOURCE_3.max()))
# Out:
# EXT_SOURCE_1: Minimum Value=0.01345791 Maximim Value=0.96269277
# EXT_SOURCE_2: Minimum Value=0.00000008 Maximim Value=0.85499967
# EXT_SOURCE_3: Minimum Value=0.00052727 Maximim Value=0.89600955

# %%
# Create new fields namely FLAG_EXT_SOURCE_1, FLAG_EXT_SOURCE_2, FLAG_EXT_SOURCE_3
#   which will have a value of N when the corresponding field is having missing value
#   or else it will be Y
df_kaggle['FLAG_EXT_SOURCE_1'] = df_kaggle['EXT_SOURCE_1'].apply(lambda x: 'Y' if pd.notnull(x) else 'N')
df_kaggle['FLAG_EXT_SOURCE_2'] = df_kaggle['EXT_SOURCE_2'].apply(lambda x: 'Y' if pd.notnull(x) else 'N')
df_kaggle['FLAG_EXT_SOURCE_3'] = df_kaggle['EXT_SOURCE_3'].apply(lambda x: 'Y' if pd.notnull(x) else 'N')

# EXT_SOURCE_1, EXT_SOURCE_2, EXT_SOURCE_3 missing data interpolated with zero
df_kaggle.fillna(value={'EXT_SOURCE_1' : 0, 'EXT_SOURCE_2' : 0, 'EXT_SOURCE_3' : 0}, inplace=True)

# %%
# Analysis of missing data in the fields 'DEF_60_CNT_SOCIAL_CIRCLE', 'OBS_60_CNT_SOCIAL_CIRCLE', 
#      'DEF_30_CNT_SOCIAL_CIRCLE', 'OBS_30_CNT_SOCIAL_CIRCLE'
# From the Dendogram of the missing data field created before, we know that these four fields are missing 
#  for same records all at the same time.
# And since these fields shows social circle information, we created a new field 
#   namely "FLAG_SOCIAL_CIRCLE_AVAILABLE" which has value of N when these fields are having missing information
#   else Y. Once that field is created, missing values in these fields will be set to zero.
df_kaggle['FLAG_SOCIAL_CIRCLE_AVAILABLE'] = df_kaggle['DEF_30_CNT_SOCIAL_CIRCLE'].apply(lambda x: 
        'Y' if pd.notnull(x) else 'N')
df_kaggle.fillna(value={'DEF_60_CNT_SOCIAL_CIRCLE': 0, 'OBS_60_CNT_SOCIAL_CIRCLE': 0, 'DEF_30_CNT_SOCIAL_CIRCLE': 0, 
        'OBS_30_CNT_SOCIAL_CIRCLE': 0}, inplace=True)

# %%
# Analysis of missing data in the fields 'AMT_REQ_CREDIT_BUREAU_HOUR', 'AMT_REQ_CREDIT_BUREAU_DAY', 
#      'AMT_REQ_CREDIT_BUREAU_WEEK', 'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_QRT',
#      'AMT_REQ_CREDIT_BUREAU_YEAR'
# From the Dendogram of the missing data field created before, we know that these six fields are missing 
#  for same records all at the same time.
# And since these fields shows data from credit bureau, we created a new field 
#   namely "FLAG_CREDIT_BUREAU_CHECK" which has value of Y when these fields are having missing information
#   else N. Once that field is created, missing values in these fields will be set to zero.
df_kaggle['FLAG_CREDIT_BUREAU_CHECK'] = df_kaggle['AMT_REQ_CREDIT_BUREAU_HOUR'].apply(lambda x: 
        'Y' if pd.notnull(x) else 'N')
df_kaggle.fillna(value={'AMT_REQ_CREDIT_BUREAU_HOUR': 0, 'AMT_REQ_CREDIT_BUREAU_DAY': 0, 
    'AMT_REQ_CREDIT_BUREAU_WEEK': 0, 'AMT_REQ_CREDIT_BUREAU_MON': 0, 'AMT_REQ_CREDIT_BUREAU_QRT': 0,
    'AMT_REQ_CREDIT_BUREAU_YEAR': 0}, inplace=True)

# %%
# DAYS_LAST_PHONE_CHANGE missing data analysis
# Since only one record is having DAYS_LAST_PHONE_CHANGE value missing, interpolate it with zero
df_kaggle.fillna(value={'DAYS_LAST_PHONE_CHANGE': 0}, inplace=True)

# %%
# CNT_FAM_MEMBERS missing data analysis
# View other family data fields which can give clue regarding the family member size of the individual
df_kaggle[df_kaggle.CNT_FAM_MEMBERS.isnull()][['SK_ID_CURR','CNT_FAM_MEMBERS','CNT_CHILDREN',
    'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE']]
# Out:
#         SK_ID_CURR  CNT_FAM_MEMBERS  CNT_CHILDREN NAME_FAMILY_STATUS  \
# 41982       148605              NaN             0            Unknown
# 187348      317181              NaN             0            Unknown
#
#           NAME_HOUSING_TYPE
# 41982   Municipal apartment
# 187348    House / apartment

# %%
# For both of these individuals, looking at the data, we cannot say if he is single or has family.
# So missing values of CNT_FAM_MEMBERS replaced with 0
df_kaggle.fillna(value={'CNT_FAM_MEMBERS': 0}, inplace=True)

# %%
# AMT_ANNUITY and AMT_GOODS_PRICE missing data anlysis
# Since given the dataset, we have not way to find the missing values of these fields untill unless we run 
#   some interpolation algorithms which will try to interpolate the missing values of these fields
#   based of data from other similar clients. But since the records with missing values of these fields are
#   very less (AMT_ANNUITY is 36 and AMT_GOODS_PRICE is 278), we replaced the missing values with 0
df_kaggle.fillna(value={'AMT_ANNUITY': 0, 'AMT_GOODS_PRICE':0}, inplace=True)

# %%
# Get remaining columns having missing data
desc_1 = pd.DataFrame(df_kaggle.dtypes, columns=['type']).join(df_kaggle.describe(include='all').T)
desc_1 = desc_1[desc_1['count']<df_kaggle['TARGET'].size][['count', 'type']]
desc_1.index
# Out:
# Index(['APARTMENTS_AVG', 'BASEMENTAREA_AVG', 'YEARS_BEGINEXPLUATATION_AVG',
#        'YEARS_BUILD_AVG', 'COMMONAREA_AVG', 'ELEVATORS_AVG', 'ENTRANCES_AVG',
#        'FLOORSMAX_AVG', 'FLOORSMIN_AVG', 'LANDAREA_AVG',
#        'LIVINGAPARTMENTS_AVG', 'LIVINGAREA_AVG', 'NONLIVINGAPARTMENTS_AVG',
#        'NONLIVINGAREA_AVG', 'APARTMENTS_MODE', 'BASEMENTAREA_MODE',
#        'YEARS_BEGINEXPLUATATION_MODE', 'YEARS_BUILD_MODE', 'COMMONAREA_MODE',
#        'ELEVATORS_MODE', 'ENTRANCES_MODE', 'FLOORSMAX_MODE', 'FLOORSMIN_MODE',
#        'LANDAREA_MODE', 'LIVINGAPARTMENTS_MODE', 'LIVINGAREA_MODE',
#        'NONLIVINGAPARTMENTS_MODE', 'NONLIVINGAREA_MODE', 'APARTMENTS_MEDI',
#        'BASEMENTAREA_MEDI', 'YEARS_BEGINEXPLUATATION_MEDI', 'YEARS_BUILD_MEDI',
#        'COMMONAREA_MEDI', 'ELEVATORS_MEDI', 'ENTRANCES_MEDI', 'FLOORSMAX_MEDI',
#        'FLOORSMIN_MEDI', 'LANDAREA_MEDI', 'LIVINGAPARTMENTS_MEDI',
#        'LIVINGAREA_MEDI', 'NONLIVINGAPARTMENTS_MEDI', 'NONLIVINGAREA_MEDI',
# ...

# %%
# All the remaining fields which have missing data are associated to the place where the client lives
#  So if its missing, it may mean that the client has not provided this information or that information
#  is not applicable to the place where the client currently stays
#  So the missing values in all these fields were replaced by zero
df_kaggle.fillna(value={'APARTMENTS_AVG': 0, 'BASEMENTAREA_AVG': 0, 'YEARS_BEGINEXPLUATATION_AVG': 0,
       'YEARS_BUILD_AVG': 0, 'COMMONAREA_AVG': 0, 'ELEVATORS_AVG': 0, 'ENTRANCES_AVG': 0,
       'FLOORSMAX_AVG': 0, 'FLOORSMIN_AVG': 0, 'LANDAREA_AVG': 0,
       'LIVINGAPARTMENTS_AVG': 0, 'LIVINGAREA_AVG': 0, 'NONLIVINGAPARTMENTS_AVG': 0,
       'NONLIVINGAREA_AVG': 0, 'APARTMENTS_MODE': 0, 'BASEMENTAREA_MODE': 0,
       'YEARS_BEGINEXPLUATATION_MODE': 0, 'YEARS_BUILD_MODE': 0, 'COMMONAREA_MODE': 0,
       'ELEVATORS_MODE': 0, 'ENTRANCES_MODE': 0, 'FLOORSMAX_MODE': 0, 'FLOORSMIN_MODE': 0,
       'LANDAREA_MODE': 0, 'LIVINGAPARTMENTS_MODE': 0, 'LIVINGAREA_MODE': 0,
       'NONLIVINGAPARTMENTS_MODE': 0, 'NONLIVINGAREA_MODE': 0, 'APARTMENTS_MEDI': 0,
       'BASEMENTAREA_MEDI': 0, 'YEARS_BEGINEXPLUATATION_MEDI': 0, 'YEARS_BUILD_MEDI': 0,
       'COMMONAREA_MEDI': 0, 'ELEVATORS_MEDI': 0, 'ENTRANCES_MEDI': 0, 'FLOORSMAX_MEDI': 0,
       'FLOORSMIN_MEDI': 0, 'LANDAREA_MEDI': 0, 'LIVINGAPARTMENTS_MEDI': 0,
       'LIVINGAREA_MEDI': 0, 'NONLIVINGAPARTMENTS_MEDI': 0, 'NONLIVINGAREA_MEDI': 0,
       'TOTALAREA_MODE': 0}, inplace=True)

# %%
# Save the cleaned dataset in csv file
df_kaggle.to_csv('Cleaned_Application_Data.csv', index = False)
